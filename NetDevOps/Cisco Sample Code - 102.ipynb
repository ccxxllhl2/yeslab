# %% [markdown]
# # Cisco Sample Code
# ## 102 REST

# %%
import requests
import json
from helper.spark import *

requests.packages.urllib3.disable_warnings()

controller='sandboxapicem.cisco.com'
username = "devnetuser"
password = "Cisco123!"
version = "v1"

# %% [markdown]
# ## 通用函数

# %%
def getTicket():
    # put the ip address or dns of your apic-em controller in this url
    url = "https://" + controller + "/api/v1/ticket"

    #the username and password to access the APIC-EM Controller    
    payload = {"username":username,"password":password}

    #Content type must be included in the header
    header = {"content-type": "application/json"}

    #Performs a POST on the specified url to get the service ticket
    response= requests.post(url,data=json.dumps(payload), headers=header, verify=False)

    print (response)
    
    #convert response to json format
    r_json=response.json()

    #parse the json to get the service ticket
    ticket = r_json["response"]["serviceTicket"]

    return ticket

# %% [markdown]
# ### Build Topology

# %%
def getTopology():
    ticket=getTicket()
    
    # URL for topology REST API call to get list of existing devices on the network, and build topology
    url = "https://" + controller + "/api/v1/topology/physical-topology"

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}

    # this statement performs a GET on the specified network device url
    response = requests.get(url, headers=header, verify=False)

    # json.dumps serializes the json into a string and allows us to
    # print the response in a 'pretty' format with indentation etc.
    print ("Topology = ")
    print (json.dumps(response.json(), indent=4, separators=(',', ': ')))
    
    #convert data to json format.
    r_json=response.json()
    
    #Iterate through network device data and list the nodes, their interfaces, status and to what they connect    
    for n in r_json["response"]["nodes"]:
        if "platformId" in n:
            print()
            print()
            print('{:30}'.format("Node") + '{:25}'.format("Family") + '{:20}'.format("Label")+ "Management IP")
            print('{:30}'.format(n["platformId"]) + '{:25}'.format(n["family"]) + '{:20}'.format(n["label"]) + n["ip"])        
        found=0    #print header flag
        printed=0  #formatting flag
        for i in r_json["response"]["links"]:
            if "startPortName" in i:
                #check that the source device id for the interface matches the node id.  Means interface originated from this device. 
                if i["source"] == n["id"]:
                    if found==0:
                        print('{:>20}'.format("Source Interface") + '{:>15}'.format("Target") +'{:>28}'.format("Target Interface") + '{:>15}'.format("Status") )
                        found=1
                        printed=1                    
                    for n1 in r_json["response"]["nodes"]:
                        #find name of node to which this one connects
                        if i["target"] == n1["id"]:
                            print("    " + '{:<25}'.format(i["startPortName"]) + '{:<18}'.format(n1["platformId"]) + '{:<25}'.format(i["endPortName"]) + '{:<9}'.format(i["linkStatus"]) )                            
                            break;
        found=0        
        
        for i in r_json["response"]["links"]:
            if "startPortName" in i:
                #Find interfaces that link to this one which means this node is the target. 
                if i["target"] == n["id"]:
                    if found==0:
                        if printed==1:
                            print()
                        print('{:>10}'.format("Source") + '{:>30}'.format("Source Interface") + '{:>25}'.format("Target Interface") + '{:>13}'.format("Status"))
                        found=1                    
                    for n1 in r_json["response"]["nodes"]:
                        #find name of node to that connects to this one
                        if i["source"] == n1["id"]:                            
                            print("    " + '{:<20}'.format(n1["platformId"]) + '{:<25}'.format(i["startPortName"]) + '{:<23}'.format(i["endPortName"]) + '{:<8}'.format(i["linkStatus"]))
                            break;
        

getTopology()
# Out:
# <Response [200]>
# Topology =
# {
#     "response": {
#         "nodes": [
#             {
#                 "deviceType": "Cisco 2911 Integrated Services Router G2",
#                 "label": "Branch-Router1",
#                 "ip": "10.2.2.1",
#                 "softwareVersion": "15.2(4)M6a",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "CISCO2911/K9",
#                 "tags": [
#                     "test3"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "0dd240fd-5cca-4774-a801-9f1c04edcc70"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 6503 Switch",
#                 "label": "CAMPUS-Core2",
#                 "ip": "10.1.10.1",
#                 "softwareVersion": "15.2(1)SY1",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C6503-E",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "1b329f52-95eb-44ad-9314-55932162ab86"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 29xx Stack-able Ethernet Switch",
#                 "label": "Branch-Access1",
#                 "ip": "10.2.1.17",
#                 "softwareVersion": "12.2(55)SE3",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C2960S-48LPS-L",
#                 "tags": [
#                     "test3",
#                     "test",
#                     "Test1"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "26450a30-57d8-4b56-b8f1-6fc535d67645"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 6503 Switch",
#                 "label": "CAMPUS-Core1",
#                 "ip": "10.1.7.1",
#                 "softwareVersion": "15.2(1)SY1",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C6503-E",
#                 "tags": [],
#                 "role": "CORE",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "30d39b18-9ada-4148-ad6c-2ee20975b845"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 4507R plus E Switch",
#                 "label": "CAMPUS-Dist2",
#                 "ip": "10.1.11.1",
#                 "softwareVersion": "03.04.00.SG",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C4507R+E",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22"
#             },
#             {
#                 "deviceType": "Cisco 4451 Series Integrated Services Router",
#                 "label": "CAMPUS-Router2",
#                 "ip": "10.1.4.2",
#                 "softwareVersion": "15.4(3)S",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "ISR4451-X/K9",
#                 "tags": [
#                     "test3",
#                     "Test1"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "55450140-de19-47b5-ae80-bfd741b23fd9"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 3850-48U-E Switch",
#                 "label": "CAMPUS-Access1",
#                 "ip": "10.1.12.1",
#                 "softwareVersion": "03.06.04.E",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C3850-48U",
#                 "tags": [],
#                 "role": "CORE",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "5b5ea8da-8c23-486a-b95e-7429684d25fc"
#             },
#             {
#                 "deviceType": "Cisco 2911 Integrated Services Router G2",
#                 "label": "Branch-Router2",
#                 "ip": "10.2.2.2",
#                 "softwareVersion": "15.2(4)M6a",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "CISCO2911/K9",
#                 "tags": [
#                     "test3",
#                     "Test1"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "6ce631db-9212-4587-867f-b8f3aed1702d"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 2960C-8PC-L Switch",
#                 "label": "AHEC-2960C1",
#                 "ip": "165.10.1.39",
#                 "softwareVersion": "15.2(2.5.72)E4",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C2960C-8PC-L",
#                 "tags": [
#                     "test3",
#                     "test",
#                     "Test1"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7"
#             },
#             {
#                 "deviceType": "Cisco 4451 Series Integrated Services Router",
#                 "label": "CAMPUS-Router1",
#                 "ip": "10.1.2.1",
#                 "softwareVersion": "15.4(3)S",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "ISR4451-X/K9",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7"
#             },
#             {
#                 "deviceType": "Cisco 5508 Wireless LAN Controller",
#                 "label": "Campus-WLC-5508",
#                 "ip": "10.1.14.2",
#                 "softwareVersion": "8.1.14.16",
#                 "nodeType": "device",
#                 "family": "Wireless Controller",
#                 "platformId": "AIR-CT5508-K9",
#                 "tags": [
#                     "test3",
#                     "Test1"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 4507R plus E Switch",
#                 "label": "CAMPUS-Dist1",
#                 "ip": "10.255.1.5",
#                 "softwareVersion": "03.02.00.XO",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C4507R+E",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "c8ed3e49-5eeb-4dee-b120-edeb179c8394"
#             },
#             {
#                 "deviceType": "Cisco 3500I Unified Access Point",
#                 "label": "AP7081.059f.19ca",
#                 "ip": "10.1.14.3",
#                 "softwareVersion": "8.1.14.16",
#                 "nodeType": "device",
#                 "family": "Unified AP",
#                 "platformId": "AIR-CAP3502I-A-K9",
#                 "tags": [
#                     "Test1"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "cd6d9b24-839b-4d58-adfe-3fdf781e1782"
#             },
#             {
#                 "deviceType": "Cisco 2911 Integrated Services Router G2",
#                 "label": "Branch2-Router.yourdomain.com",
#                 "ip": "218.1.100.100",
#                 "softwareVersion": "15.2(4)M6a",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "CISCO2911/K9",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "d337811b-d371-444c-a49f-9e2791f955b4"
#             },
#             {
#                 "deviceType": "wireless",
#                 "label": "10.1.15.117",
#                 "ip": "10.1.15.117",
#                 "nodeType": "HOST",
#                 "family": "WIRELESS",
#                 "role": "HOST",
#                 "customParam": {},
#                 "id": "48cdeb9b-b412-491e-a80c-7ec5bbe98167"
#             },
#             {
#                 "deviceType": "wired",
#                 "label": "10.1.12.20",
#                 "ip": "10.1.12.20",
#                 "nodeType": "HOST",
#                 "family": "WIRED",
#                 "role": "HOST",
#                 "customParam": {},
#                 "id": "572d4065-abd8-4b97-bfc3-ab5ee13f6c08"
#             },
#             {
#                 "deviceType": "wired",
#                 "label": "10.2.1.22",
#                 "ip": "10.2.1.22",
#                 "nodeType": "HOST",
#                 "family": "WIRED",
#                 "role": "HOST",
#                 "customParam": {},
#                 "id": "f624d4f3-0ab9-4ae3-b09d-62051edbd8f3"
#             },
#             {
#                 "deviceType": "cloud node",
#                 "label": "cloud node",
#                 "ip": "UNKNOWN",
#                 "softwareVersion": "UNKNOWN",
#                 "nodeType": "cloud node",
#                 "family": "cloud node",
#                 "platformId": "UNKNOWN",
#                 "tags": [
#                     "cloud node"
#                 ],
#                 "role": "cloud node",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "e670f633-49c9-4132-9cac-bc91d730a555"
#             }
#         ],
#         "links": [
#             {
#                 "source": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "startPortID": "1ac5854f-4659-442f-9bd2-f775aa3b260a",
#                 "startPortName": "GigabitEthernet5/38",
#                 "startPortSpeed": "1000000",
#                 "target": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#                 "endPortID": "4f063bed-7ca8-49dc-8fd4-63ff1613d59f",
#                 "endPortName": "GigabitEthernet0/0/1",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97107"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "7710a7b4-fc96-43e4-a1bf-b002c052d6f2",
#                 "startPortName": "GigabitEthernet1/2",
#                 "startPortIpv4Address": "10.1.5.2",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#                 "endPortID": "6dc56935-8268-45e4-acaa-de1c15a8832d",
#                 "endPortName": "GigabitEthernet0/0/1",
#                 "endPortIpv4Address": "10.1.5.1",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97100"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "f8a45bfd-0e1f-4f3e-b56c-150e3a9fc103",
#                 "startPortName": "GigabitEthernet1/1",
#                 "startPortIpv4Address": "10.1.7.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "endPortID": "729002b4-a1cd-4700-a2f9-b68cbdfe2f70",
#                 "endPortName": "GigabitEthernet5/7",
#                 "endPortIpv4Address": "10.1.7.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97103"
#             },
#             {
#                 "source": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "startPortID": "05186c34-2ed8-4db4-bba3-ac9c2b68ad90",
#                 "startPortName": "GigabitEthernet1/0/1",
#                 "startPortSpeed": "1000000",
#                 "target": "6ce631db-9212-4587-867f-b8f3aed1702d",
#                 "endPortID": "1b46c64c-bb92-4998-bee2-283118075156",
#                 "endPortName": "GigabitEthernet0/2",
#                 "endPortIpv4Address": "10.2.1.19",
#                 "endPortIpv4Mask": "255.255.255.0",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97098"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "51338919-c3a8-401d-96d9-14cc1de9efda",
#                 "startPortName": "GigabitEthernet1/3",
#                 "startPortIpv4Address": "10.1.4.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "55450140-de19-47b5-ae80-bfd741b23fd9",
#                 "endPortID": "76fe51df-dee7-4041-944c-a49244172a00",
#                 "endPortName": "GigabitEthernet0/0/0",
#                 "endPortIpv4Address": "10.1.4.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97106"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "22f37b71-25f3-4b9a-945a-2c7d28345540",
#                 "startPortName": "TenGigabitEthernet1/5",
#                 "startPortIpv4Address": "10.1.10.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "10000000",
#                 "target": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "endPortID": "0b2984dd-7dbd-4cf3-9308-246bcf31673c",
#                 "endPortName": "TenGigabitEthernet3/1",
#                 "endPortIpv4Address": "10.1.10.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "10000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97102"
#             },
#             {
#                 "source": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#                 "startPortID": "117ef150-0fcd-4c34-9b7d-92c31af82627",
#                 "startPortName": "GigabitEthernet0/1",
#                 "startPortIpv4Address": "10.2.2.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "6ce631db-9212-4587-867f-b8f3aed1702d",
#                 "endPortID": "c21a4fd0-c571-4516-980e-3f118cb827ec",
#                 "endPortName": "GigabitEthernet0/1",
#                 "endPortIpv4Address": "10.2.2.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97114"
#             },
#             {
#                 "source": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "startPortID": "a6355c85-3577-4922-bfe5-1c08456b7cae",
#                 "startPortName": "GigabitEthernet1/0/2",
#                 "startPortSpeed": "1000000",
#                 "target": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#                 "endPortID": "4ab54405-1b5a-4ddc-9950-20af65f6806c",
#                 "endPortName": "GigabitEthernet0/2",
#                 "endPortIpv4Address": "10.2.1.18",
#                 "endPortIpv4Mask": "255.255.255.0",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97097"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "8e3fd588-deef-4dc8-9885-560e0f48bf49",
#                 "startPortName": "GigabitEthernet1/3",
#                 "startPortIpv4Address": "10.1.3.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "55450140-de19-47b5-ae80-bfd741b23fd9",
#                 "endPortID": "20c9326c-82b0-47b9-aee5-f57b7725bd01",
#                 "endPortName": "GigabitEthernet0/0/1",
#                 "endPortIpv4Address": "10.1.3.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97099"
#             },
#             {
#                 "source": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#                 "startPortID": "ea5e2530-a43e-4111-8858-719d7764b368",
#                 "startPortName": "GigabitEthernet0/0/2",
#                 "startPortIpv4Address": "10.1.1.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "55450140-de19-47b5-ae80-bfd741b23fd9",
#                 "endPortID": "cb43a099-28d6-4b3d-a741-fb2dbd024748",
#                 "endPortName": "GigabitEthernet0/0/2",
#                 "endPortIpv4Address": "10.1.1.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97113"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "e37e041c-e005-42e1-bce7-4c2587e10f76",
#                 "startPortName": "TenGigabitEthernet1/5",
#                 "startPortIpv4Address": "10.1.9.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "10000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "fa5b0690-8b64-4392-832d-b95f180dd5d8",
#                 "endPortName": "TenGigabitEthernet3/1",
#                 "endPortIpv4Address": "10.1.9.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "10000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97104"
#             },
#             {
#                 "source": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#                 "startPortID": "",
#                 "startPortName": "GigabitEthernet0",
#                 "startPortIpv4Address": " 10.  1. 14.  3",
#                 "startPortIpv4Mask": "255.255.255.  0",
#                 "startPortSpeed": "-1",
#                 "target": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "endPortID": "dd2c47ea-ad19-4a1e-ad0e-82d9deefd61b",
#                 "endPortName": "GigabitEthernet1/0/26",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97116"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "f6a66400-3fda-4511-80af-4413f70f0827",
#                 "startPortName": "GigabitEthernet1/1",
#                 "startPortIpv4Address": "10.1.8.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "3dad05bd-1b78-466f-94fe-1921bc0e3c15",
#                 "endPortName": "GigabitEthernet5/7",
#                 "endPortIpv4Address": "10.1.8.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97101"
#             },
#             {
#                 "source": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "startPortID": "2c563c32-fefa-48f0-b960-160712f9f9f7",
#                 "startPortName": "GigabitEthernet5/48",
#                 "startPortIpv4Address": "10.1.11.2",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "146f21fa-bc0c-4081-bb22-affde24cdd9f",
#                 "endPortName": "GigabitEthernet5/48",
#                 "endPortIpv4Address": "10.1.11.1",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97108"
#             },
#             {
#                 "source": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "startPortID": "f1fc2715-25e0-4b92-9fa5-e34237cbc1c8",
#                 "startPortName": "GigabitEthernet1/0/2",
#                 "startPortSpeed": "1000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "58f7c3b1-99df-4965-9c1f-c0a284772f64",
#                 "endPortName": "GigabitEthernet5/5",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97112"
#             },
#             {
#                 "source": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "startPortID": "38c72319-855e-43bc-8458-94f695d435b6",
#                 "startPortName": "GigabitEthernet1/0/1",
#                 "startPortSpeed": "1000000",
#                 "target": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "endPortID": "b10dcdea-1675-4509-b554-f047f6a37595",
#                 "endPortName": "GigabitEthernet5/5",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97110"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "6df9d717-5c7a-479e-a595-563480aaada0",
#                 "startPortName": "GigabitEthernet1/2",
#                 "startPortIpv4Address": "10.1.2.2",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#                 "endPortID": "43ee5993-b8a0-4ed8-8c1b-376273834582",
#                 "endPortName": "GigabitEthernet0/0/0",
#                 "endPortIpv4Address": "10.1.2.1",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97105"
#             },
#             {
#                 "source": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7",
#                 "startPortID": "8d235543-bb80-4423-b66f-1e9ad45d08e6",
#                 "startPortName": "FastEthernet0/1",
#                 "startPortSpeed": "100000",
#                 "target": "d337811b-d371-444c-a49f-9e2791f955b4",
#                 "endPortID": "fc78fa72-a37e-46c7-9f47-137789295e35",
#                 "endPortName": "GigabitEthernet0/0.1",
#                 "endPortIpv4Address": "165.10.1.100",
#                 "endPortIpv4Mask": "255.255.255.0",
#                 "endPortSpeed": "100000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97118"
#             },
#             {
#                 "source": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#                 "target": "48cdeb9b-b412-491e-a80c-7ec5bbe98167",
#                 "linkStatus": "UP",
#                 "greyOut": true
#             },
#             {
#                 "source": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "startPortID": "6e4e5ae6-6045-4060-9038-1a64d5a101cc",
#                 "target": "572d4065-abd8-4b97-bfc3-ab5ee13f6c08",
#                 "linkStatus": "UP",
#                 "greyOut": true
#             },
#             {
#                 "source": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "startPortID": "7075521d-4d7b-4218-92f9-79b60e054635",
#                 "target": "f624d4f3-0ab9-4ae3-b09d-62051edbd8f3",
#                 "linkStatus": "UP",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#                 "linkStatus": "up",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "linkStatus": "up",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "6ce631db-9212-4587-867f-b8f3aed1702d",
#                 "linkStatus": "up",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "d337811b-d371-444c-a49f-9e2791f955b4",
#                 "linkStatus": "up",
#                 "greyOut": true
#             }
#         ]
#     },
#     "version": "1.0"
# }
#
#
# Node                          Family                   Label               Management IP
# CISCO2911/K9                  Routers                  Branch-Router1      10.2.2.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet0/1       CISCO2911/K9      GigabitEthernet0/1       up
#
#     Source              Source Interface         Target Interface       Status
#     WS-C2960S-48LPS-L   GigabitEthernet1/0/2     GigabitEthernet0/2     up
#
#
# Node                          Family                   Label               Management IP
# WS-C6503-E                    Switches and Hubs        CAMPUS-Core2        10.1.10.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/2       ISR4451-X/K9      GigabitEthernet0/0/1     up
#     TenGigabitEthernet1/5    WS-C4507R+E       TenGigabitEthernet3/1    up
#     GigabitEthernet1/3       ISR4451-X/K9      GigabitEthernet0/0/1     up
#     GigabitEthernet1/1       WS-C4507R+E       GigabitEthernet5/7       up
#
#
# Node                          Family                   Label               Management IP
# WS-C2960S-48LPS-L             Switches and Hubs        Branch-Access1      10.2.1.17
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/0/1     CISCO2911/K9      GigabitEthernet0/2       up
#     GigabitEthernet1/0/2     CISCO2911/K9      GigabitEthernet0/2       up
#
#
# Node                          Family                   Label               Management IP
# WS-C6503-E                    Switches and Hubs        CAMPUS-Core1        10.1.7.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/1       WS-C4507R+E       GigabitEthernet5/7       up
#     GigabitEthernet1/3       ISR4451-X/K9      GigabitEthernet0/0/0     up
#     TenGigabitEthernet1/5    WS-C4507R+E       TenGigabitEthernet3/1    up
#     GigabitEthernet1/2       ISR4451-X/K9      GigabitEthernet0/0/0     up
#
#
# Node                          Family                   Label               Management IP
# WS-C4507R+E                   Switches and Hubs        CAMPUS-Dist2        10.1.11.1
#     Source              Source Interface         Target Interface       Status
#     WS-C6503-E          TenGigabitEthernet1/5    TenGigabitEthernet3/1  up
#     WS-C6503-E          GigabitEthernet1/1       GigabitEthernet5/7     up
#     WS-C4507R+E         GigabitEthernet5/48      GigabitEthernet5/48    up
#     WS-C3850-48U        GigabitEthernet1/0/2     GigabitEthernet5/5     up
#
#
# Node                          Family                   Label               Management IP
# ISR4451-X/K9                  Routers                  CAMPUS-Router2      10.1.4.2
#     Source              Source Interface         Target Interface       Status
#     WS-C6503-E          GigabitEthernet1/3       GigabitEthernet0/0/0   up
#     WS-C6503-E          GigabitEthernet1/3       GigabitEthernet0/0/1   up
#     ISR4451-X/K9        GigabitEthernet0/0/2     GigabitEthernet0/0/2   up
#
#
# Node                          Family                   Label               Management IP
# WS-C3850-48U                  Switches and Hubs        CAMPUS-Access1      10.1.12.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/0/2     WS-C4507R+E       GigabitEthernet5/5       up
#     GigabitEthernet1/0/1     WS-C4507R+E       GigabitEthernet5/5       up
#
#     Source              Source Interface         Target Interface       Status
#     AIR-CAP3502I-A-K9   GigabitEthernet0         GigabitEthernet1/0/26  up
#
#
# Node                          Family                   Label               Management IP
# CISCO2911/K9                  Routers                  Branch-Router2      10.2.2.2
#     Source              Source Interface         Target Interface       Status
#     WS-C2960S-48LPS-L   GigabitEthernet1/0/1     GigabitEthernet0/2     up
#     CISCO2911/K9        GigabitEthernet0/1       GigabitEthernet0/1     up
#
#
# Node                          Family                   Label               Management IP
# WS-C2960C-8PC-L               Switches and Hubs        AHEC-2960C1         165.10.1.39
#     Source Interface         Target            Target Interface         Status
#     FastEthernet0/1          CISCO2911/K9      GigabitEthernet0/0.1     up
#
#
# Node                          Family                   Label               Management IP
# ISR4451-X/K9                  Routers                  CAMPUS-Router1      10.1.2.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet0/0/2     ISR4451-X/K9      GigabitEthernet0/0/2     up
#
#     Source              Source Interface         Target Interface       Status
#     WS-C6503-E          GigabitEthernet1/2       GigabitEthernet0/0/1   up
#     WS-C6503-E          GigabitEthernet1/2       GigabitEthernet0/0/0   up
#
#
# Node                          Family                   Label               Management IP
# AIR-CT5508-K9                 Wireless Controller      Campus-WLC-5508     10.1.14.2
#     Source              Source Interface         Target Interface       Status
#     WS-C4507R+E         GigabitEthernet5/38      GigabitEthernet0/0/1   up
#
#
# Node                          Family                   Label               Management IP
# WS-C4507R+E                   Switches and Hubs        CAMPUS-Dist1        10.255.1.5
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet5/38      AIR-CT5508-K9     GigabitEthernet0/0/1     up
#     GigabitEthernet5/48      WS-C4507R+E       GigabitEthernet5/48      up
#
#     Source              Source Interface         Target Interface       Status
#     WS-C6503-E          GigabitEthernet1/1       GigabitEthernet5/7     up
#     WS-C6503-E          TenGigabitEthernet1/5    TenGigabitEthernet3/1  up
#     WS-C3850-48U        GigabitEthernet1/0/1     GigabitEthernet5/5     up
#
#
# Node                          Family                   Label               Management IP
# AIR-CAP3502I-A-K9             Unified AP               AP7081.059f.19ca    10.1.14.3
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet0         WS-C3850-48U      GigabitEthernet1/0/26    up
#
#
# Node                          Family                   Label               Management IP
# CISCO2911/K9                  Routers                  Branch2-Router.yourdomain.com218.1.100.100
#     Source              Source Interface         Target Interface       Status
#     WS-C2960C-8PC-L     FastEthernet0/1          GigabitEthernet0/0.1   up
#
#
# Node                          Family                   Label               Management IP
# UNKNOWN                       cloud node               cloud node          UNKNOWN

# %% [markdown]
# ### Get Network Devices

# %%
def getNetworkDevices():
    
    ticket=getTicket()
    
    # URL for network-device REST API call to get list of exisiting devices on the network.
    url = "https://" + controller + "/api/v1/network-device"

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}

    # this statement performs a GET on the specified network device url
    response = requests.get(url, headers=header, verify=False)

    # json.dumps serializes the json into a string and allows us to
    # print the response in a 'pretty' format with indentation etc.
    print ("Network Devices = ")
    print (json.dumps(response.json(), indent=4, separators=(',', ': ')))
    
    #convert data to json format.
    r_json=response.json()
    
    #Iterate through network device data and print the id and series name of each device
    for i in r_json["response"]:
        print(i["id"] + "   " + '{:53}'.format(i["series"]) + "  " + i["reachabilityStatus"])
        
    return r_json, response
        

r_json, response = getNetworkDevices()
# Out:
# <Response [200]>
# Network Devices =
# {
#     "response": [
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FOC1637Y3FJ",
#             "macAddress": "54:78:1a:8e:28:c0",
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 2960C-8PC-L Switch",
#             "location": "df8a7d62-a156-4fcd-8573-cc1421f7a14d",
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "16:11:38.75",
#             "role": "DISTRIBUTION",
#             "lastUpdated": "2020-02-22 06:17:05",
#             "softwareVersion": "15.2(2.5.72)E4",
#             "lastUpdateTime": 1582352225100,
#             "locationName": "Riyadh",
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "3",
#             "hostname": "AHEC-2960C1",
#             "series": "Cisco Catalyst 2960-C Series Switches",
#             "lineCardCount": "1",
#             "lineCardId": "b77af8c6-bfa2-4388-9cbc-5e36f72090bf",
#             "managementIpAddress": "165.10.1.39",
#             "memorySize": "59556224",
#             "platformId": "WS-C2960C-8PC-L",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-11-18 07:54:31",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "11",
#             "instanceUuid": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7",
#             "id": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7"
#         },
#         {
#             "errorCode": "null",
#             "serialNumber": "FGL1548S2YF",
#             "macAddress": "68:bc:0c:63:4a:b0",
#             "family": "Unified AP",
#             "type": "Cisco 3500I Unified Access Point",
#             "location": null,
#             "inventoryStatusDetail": "NA",
#             "upTime": null,
#             "role": "ACCESS",
#             "lastUpdated": "2020-02-22 06:18:26",
#             "softwareVersion": "8.1.14.16",
#             "lastUpdateTime": 1582352306578,
#             "locationName": null,
#             "errorDescription": null,
#             "tagCount": "1",
#             "hostname": "AP7081.059f.19ca",
#             "series": "Cisco 3500I Series Unified Access Points",
#             "lineCardCount": null,
#             "lineCardId": null,
#             "managementIpAddress": "10.1.14.3",
#             "memorySize": "NA",
#             "platformId": "AIR-CAP3502I-A-K9",
#             "reachabilityFailureReason": "NA",
#             "reachabilityStatus": "Reachable",
#             "roleSource": "AUTO",
#             "snmpContact": "",
#             "snmpLocation": "default location",
#             "tunnelUdpPort": "16666",
#             "apManagerInterfaceIp": "10.1.14.2",
#             "bootDateTime": null,
#             "collectionStatus": "Managed",
#             "interfaceCount": null,
#             "instanceUuid": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#             "id": "cd6d9b24-839b-4d58-adfe-3fdf781e1782"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FOC1537W1ZY",
#             "macAddress": "64:a0:e7:d4:9b:c1",
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 29xx Stack-able Ethernet Switch",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "219 days, 21:09:28.84",
#             "role": "BORDER ROUTER",
#             "lastUpdated": "2020-02-22 06:18:39",
#             "softwareVersion": "12.2(55)SE3",
#             "lastUpdateTime": 1582352319014,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "3",
#             "hostname": "Branch-Access1",
#             "series": "Cisco Catalyst 2960 Series Switches",
#             "lineCardCount": "1",
#             "lineCardId": "cbfd87b9-a8a2-48a8-8296-2947dbf81de8",
#             "managementIpAddress": "10.2.1.17",
#             "memorySize": "73969000",
#             "platformId": "WS-C2960S-48LPS-L",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-04-13 03:02:46",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "55",
#             "instanceUuid": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#             "id": "26450a30-57d8-4b56-b8f1-6fc535d67645"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FTX1840ALC1",
#             "macAddress": "7c:0e:ce:9f:3c:d9",
#             "family": "Routers",
#             "type": "Cisco 2911 Integrated Services Router G2",
#             "location": "df8a7d62-a156-4fcd-8573-cc1421f7a14d",
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "174 days, 23:37:05.56",
#             "role": "BORDER ROUTER",
#             "lastUpdated": "2020-02-22 06:12:44",
#             "softwareVersion": "15.2(4)M6a",
#             "lastUpdateTime": 1582351964296,
#             "locationName": "Riyadh",
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "1",
#             "hostname": "Branch-Router1",
#             "series": "Cisco 2900 Series Integrated Services Routers G2",
#             "lineCardCount": "1",
#             "lineCardId": "b913fc7b-ecda-4e8d-b96b-c46cc82cd6a8",
#             "managementIpAddress": "10.2.2.1",
#             "memorySize": "300214800",
#             "platformId": "CISCO2911/K9",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-05-28 00:31:46",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "7",
#             "instanceUuid": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#             "id": "0dd240fd-5cca-4774-a801-9f1c04edcc70"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FTX1840ALBY",
#             "macAddress": "f0:7f:06:bb:dc:81",
#             "family": "Routers",
#             "type": "Cisco 2911 Integrated Services Router G2",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "174 days, 23:49:53.28",
#             "role": "BORDER ROUTER",
#             "lastUpdated": "2020-02-22 06:12:32",
#             "softwareVersion": "15.2(4)M6a",
#             "lastUpdateTime": 1582351952226,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "2",
#             "hostname": "Branch-Router2",
#             "series": "Cisco 2900 Series Integrated Services Routers G2",
#             "lineCardCount": "1",
#             "lineCardId": "94da60d6-5fc3-4613-bce7-7bc03e517647",
#             "managementIpAddress": "10.2.2.2",
#             "memorySize": "300246160",
#             "platformId": "CISCO2911/K9",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "AUTO",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-05-28 00:29:46",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "7",
#             "instanceUuid": "6ce631db-9212-4587-867f-b8f3aed1702d",
#             "id": "6ce631db-9212-4587-867f-b8f3aed1702d"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FTX1840ALC0",
#             "macAddress": null,
#             "family": "Routers",
#             "type": "Cisco 2911 Integrated Services Router G2",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "354 days, 0:18:52.75",
#             "role": "BORDER ROUTER",
#             "lastUpdated": "2020-02-22 06:17:04",
#             "softwareVersion": "15.2(4)M6a",
#             "lastUpdateTime": 1582352224980,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "1",
#             "hostname": "Branch2-Router.yourdomain.com",
#             "series": "Cisco 2900 Series Integrated Services Routers G2",
#             "lineCardCount": "1",
#             "lineCardId": "41a03d20-585c-4158-b5da-89125e592148",
#             "managementIpAddress": "218.1.100.100",
#             "memorySize": "300217616",
#             "platformId": "CISCO2911/K9",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "AUTO",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2015-11-30 23:53:04",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "8",
#             "instanceUuid": "d337811b-d371-444c-a49f-9e2791f955b4",
#             "id": "d337811b-d371-444c-a49f-9e2791f955b4"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FOC1703V36B",
#             "macAddress": "f0:29:29:5c:30:e2",
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 3850-48U-E Switch",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "175 days, 0:00:54.84",
#             "role": "CORE",
#             "lastUpdated": "2020-02-22 06:18:39",
#             "softwareVersion": "03.06.04.E",
#             "lastUpdateTime": 1582352319199,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "0",
#             "hostname": "CAMPUS-Access1",
#             "series": "Cisco Catalyst 3850 Series Ethernet Stackable Switch",
#             "lineCardCount": "2",
#             "lineCardId": "4e3ad63f-36ac-4807-b2a9-e377ffc3b503, 2afe376a-b613-4695-82ba-3ed0030c37e6",
#             "managementIpAddress": "10.1.12.1",
#             "memorySize": "536870912",
#             "platformId": "WS-C3850-48U",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-05-28 00:04:15",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "62",
#             "instanceUuid": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#             "id": "5b5ea8da-8c23-486a-b95e-7429684d25fc"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FXS1825Q1PA",
#             "macAddress": "24:e9:b3:3f:b1:80",
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 6503 Switch",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "109 days, 8:08:47.24",
#             "role": "CORE",
#             "lastUpdated": "2020-02-22 06:17:05",
#             "softwareVersion": "15.2(1)SY1",
#             "lastUpdateTime": 1582352225100,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "0",
#             "hostname": "CAMPUS-Core1",
#             "series": "Cisco Catalyst 6500 Series Switches",
#             "lineCardCount": "14",
#             "lineCardId": "99629b7d-b558-4776-8258-c9059507e6ba, 98ba3828-2464-4c02-b64f-c9106fe15574, d1e8a963-9851-4afb-a044-884343c870a3, d606ceea-b457-4f3f-8b70-c2f528387df6, cd773cbf-68fc-4ffb-8a12-3efb96ece3e9, 9e721ea9-2e17-47d4-8f8f-666653ae5998, d609b8e3-0409-4139-9075-7420b4a955f0, ce5bcbca-2cfc-4185-9f9d-8f3b59b0d49d, ee0865ba-b064-4b80-a59c-85d8d3959981, 0e074792-676d-42b8-aca3-dcbc40a0f349, 3578a12a-0746-4052-9380-3bea11fc6563, 5e5ade87-3f2b-4738-847f-920420ec8f0d, 2e1ee55f-7f7a-437e-b0c9-9eafeefc71f8, 129d546d-f482-4af0-83a9-8ddfd670c75d",
#             "managementIpAddress": "10.1.7.1",
#             "memorySize": "1397215264",
#             "platformId": "WS-C6503-E",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-08-01 15:55:13",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "56",
#             "instanceUuid": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#             "id": "30d39b18-9ada-4148-ad6c-2ee20975b845"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FXS1825Q1P8",
#             "macAddress": "24:e9:b3:3f:b1:c0",
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 6503 Switch",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "226 days, 22:38:02.60",
#             "role": "DISTRIBUTION",
#             "lastUpdated": "2020-02-22 06:17:05",
#             "softwareVersion": "15.2(1)SY1",
#             "lastUpdateTime": 1582352225081,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "1",
#             "hostname": "CAMPUS-Core2",
#             "series": "Cisco Catalyst 6500 Series Switches",
#             "lineCardCount": "13",
#             "lineCardId": "e9c05ad5-7927-47ed-a7bb-00dca4c6bc3a, 282a822c-2429-45fe-93c8-95471e2235a0, 9e4bd7b4-d275-427d-8939-8b777f473201, 4559fa5e-4014-4968-b836-5e57da42e401, fd0ef08b-1e15-4b4f-b2e5-e4c1c0e0359b, a1ac1cf6-6cb3-4705-b2d3-60413eea2f0f, e7d236a7-c4d9-45da-9bda-d8af714495f2, da5cf7c8-ee9e-44d4-afb9-b78a51c30292, 1872a219-ad03-47a4-971b-d200ef1aae66, 7bdf020a-8a5b-41c3-af97-7eafdd6f88fb, bcda7746-cd09-4a28-8c6b-74e1551f423d, 6c83d6e1-c2b4-41a6-9aab-b9c8714b81b5, 6ce7447b-b310-472d-9307-7696ba81c7c8",
#             "managementIpAddress": "10.1.10.1",
#             "memorySize": "1397215264",
#             "platformId": "WS-C6503-E",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-04-06 01:25:14",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "56",
#             "instanceUuid": "1b329f52-95eb-44ad-9314-55932162ab86",
#             "id": "1b329f52-95eb-44ad-9314-55932162ab86"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FOX1524GV2Z",
#             "macAddress": null,
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 4507R plus E Switch",
#             "location": "df8a7d62-a156-4fcd-8573-cc1421f7a14d",
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "115 days, 19:22:08.43",
#             "role": "DISTRIBUTION",
#             "lastUpdated": "2020-02-22 06:22:39",
#             "softwareVersion": "03.02.00.XO",
#             "lastUpdateTime": 1582352559053,
#             "locationName": "Riyadh",
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "1",
#             "hostname": "CAMPUS-Dist1",
#             "series": "Cisco Catalyst 4500 Series Switches",
#             "lineCardCount": "2",
#             "lineCardId": "6ed4dd13-e223-4296-9ac2-5dc1a6e676ae, c1eb9026-abde-4461-abb3-7d1cda5b0927",
#             "managementIpAddress": "10.255.1.5",
#             "memorySize": "805306368",
#             "platformId": "WS-C4507R+E",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "AUTO",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-07-26 04:42:13",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "60",
#             "instanceUuid": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#             "id": "c8ed3e49-5eeb-4dee-b120-edeb179c8394"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FOX1525G5S1",
#             "macAddress": "30:e4:db:25:75:3f",
#             "family": "Switches and Hubs",
#             "type": "Cisco Catalyst 4507R plus E Switch",
#             "location": "df8a7d62-a156-4fcd-8573-cc1421f7a14d",
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "367 days, 9:12:46.03",
#             "role": "DISTRIBUTION",
#             "lastUpdated": "2020-02-22 06:17:05",
#             "softwareVersion": "03.04.00.SG",
#             "lastUpdateTime": 1582352225079,
#             "locationName": "Riyadh",
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "1",
#             "hostname": "CAMPUS-Dist2",
#             "series": "Cisco Catalyst 4500 Series Switches",
#             "lineCardCount": "2",
#             "lineCardId": "775a85cf-923a-4848-b608-a20684a67e9d, 2e7fb0e0-ca4a-4c6d-b492-06437878d6e1",
#             "managementIpAddress": "10.1.11.1",
#             "memorySize": "805306368",
#             "platformId": "WS-C4507R+E",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "AUTO",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2015-11-17 14:52:13",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "56",
#             "instanceUuid": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#             "id": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FTX1842AHM2",
#             "macAddress": "f4:4e:05:cf:2e:30",
#             "family": "Routers",
#             "type": "Cisco 4451 Series Integrated Services Router",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "220 days, 0:03:46.17",
#             "role": "ACCESS",
#             "lastUpdated": "2020-02-22 06:17:05",
#             "softwareVersion": "15.4(3)S",
#             "lastUpdateTime": 1582352225030,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "1",
#             "hostname": "CAMPUS-Router1",
#             "series": "Cisco 4400 Series Integrated Services Routers",
#             "lineCardCount": "6",
#             "lineCardId": "f84f1b1f-7341-417e-8ab9-6037cb2dff09, daa0ceb6-0383-4a22-829a-8337d4811456, 382dcfe9-971d-4109-bf59-6f9788c4333e, 03390efc-103d-4220-a540-2074c6829485, 4de117cc-badd-46ac-a747-5b14fd83d59e, 596fd2a8-7e3d-4b3c-ad0a-ffbb82122648",
#             "managementIpAddress": "10.1.2.1",
#             "memorySize": "1728629512",
#             "platformId": "ISR4451-X/K9",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2016-04-13 00:03:13",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "6",
#             "instanceUuid": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#             "id": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FTX1842AHM1",
#             "macAddress": "f4:4e:05:cf:2f:e0",
#             "family": "Routers",
#             "type": "Cisco 4451 Series Integrated Services Router",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "445 days, 18:58:51.74",
#             "role": "ACCESS",
#             "lastUpdated": "2020-02-22 06:17:05",
#             "softwareVersion": "15.4(3)S",
#             "lastUpdateTime": 1582352225063,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "2",
#             "hostname": "CAMPUS-Router2",
#             "series": "Cisco 4400 Series Integrated Services Routers",
#             "lineCardCount": "6",
#             "lineCardId": "5160d894-c2b8-4839-9600-d380867e5419, 85fb9da6-b2c0-4442-881e-d92c64fc091e, 6431ea3b-7707-4c36-a06d-4ca318d27ae0, ac440c1e-be74-491a-99d1-2dcf97f5053e, a030671f-8489-4e78-9145-f2c67873642d, 1cf7b911-1ee3-463a-a0aa-a1d42ed3aeb0",
#             "managementIpAddress": "10.1.4.2",
#             "memorySize": "1728629512",
#             "platformId": "ISR4451-X/K9",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": null,
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2015-08-31 05:08:13",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "6",
#             "instanceUuid": "55450140-de19-47b5-ae80-bfd741b23fd9",
#             "id": "55450140-de19-47b5-ae80-bfd741b23fd9"
#         },
#         {
#             "errorCode": "DEV-UNREACHED",
#             "serialNumber": "FCW1630L0JG",
#             "macAddress": "a4:93:4c:fb:a2:e0",
#             "family": "Wireless Controller",
#             "type": "Cisco 5508 Wireless LAN Controller",
#             "location": null,
#             "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#             "upTime": "497 days, 2:27:52.95",
#             "role": "ACCESS",
#             "lastUpdated": "2020-02-22 06:18:26",
#             "softwareVersion": "8.1.14.16",
#             "lastUpdateTime": 1582352306578,
#             "locationName": null,
#             "errorDescription": "SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to controller or the device is responding too slow. Please ensure correct credentials are provided in discovery/global credentials and run discovery again.  You can run the new discovery for this device alone using the \u201crange discovery\u201d feature",
#             "tagCount": "2",
#             "hostname": "Campus-WLC-5508",
#             "series": "Cisco 5500 Series Wireless LAN Controllers",
#             "lineCardCount": null,
#             "lineCardId": null,
#             "managementIpAddress": "10.1.14.2",
#             "memorySize": "1025646592",
#             "platformId": "AIR-CT5508-K9",
#             "reachabilityFailureReason": "SNMP Connectivity Failed",
#             "reachabilityStatus": "Unreachable",
#             "roleSource": "MANUAL",
#             "snmpContact": "",
#             "snmpLocation": "",
#             "tunnelUdpPort": "16666",
#             "apManagerInterfaceIp": "",
#             "bootDateTime": "2015-07-10 04:27:22",
#             "collectionStatus": "Partial Collection Failure",
#             "interfaceCount": "12",
#             "instanceUuid": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#             "id": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3"
#         }
#     ],
#     "version": "1.0"
# }
# 8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7   Cisco Catalyst 2960-C Series Switches                  Unreachable
# cd6d9b24-839b-4d58-adfe-3fdf781e1782   Cisco 3500I Series Unified Access Points               Reachable
# 26450a30-57d8-4b56-b8f1-6fc535d67645   Cisco Catalyst 2960 Series Switches                    Unreachable
# 0dd240fd-5cca-4774-a801-9f1c04edcc70   Cisco 2900 Series Integrated Services Routers G2       Unreachable
# 6ce631db-9212-4587-867f-b8f3aed1702d   Cisco 2900 Series Integrated Services Routers G2       Unreachable
# d337811b-d371-444c-a49f-9e2791f955b4   Cisco 2900 Series Integrated Services Routers G2       Unreachable
# 5b5ea8da-8c23-486a-b95e-7429684d25fc   Cisco Catalyst 3850 Series Ethernet Stackable Switch   Unreachable
# 30d39b18-9ada-4148-ad6c-2ee20975b845   Cisco Catalyst 6500 Series Switches                    Unreachable
# 1b329f52-95eb-44ad-9314-55932162ab86   Cisco Catalyst 6500 Series Switches                    Unreachable
# c8ed3e49-5eeb-4dee-b120-edeb179c8394   Cisco Catalyst 4500 Series Switches                    Unreachable
# 4af8bf34-295f-46f4-97b7-0a2d2ea4cf22   Cisco Catalyst 4500 Series Switches                    Unreachable
# 9712ab62-6140-43fd-b1ee-1b07d1fb67d7   Cisco 4400 Series Integrated Services Routers          Unreachable
# 55450140-de19-47b5-ae80-bfd741b23fd9   Cisco 4400 Series Integrated Services Routers          Unreachable
# ae19cd21-1b26-4f58-8ccd-d265deabb6c3   Cisco 5500 Series Wireless LAN Controllers             Unreachable

# %% [markdown]
# ### Get Network Hosts

# %%
def getNetworkHosts():
    ticket=getTicket()
    url = "https://" + controller + "/api/v1/host?limit=1&offset=1"
    header = {"content-type": "application/json", "X-Auth-Token":ticket}
    response = requests.get(url, headers=header, verify=False)
    r_json = response.json()
    print ("Hosts = ")
    print (json.dumps(r_json, indent=4, separators=(',', ': ')))
    
getNetworkHosts()
# Out:
# <Response [200]>
# Hosts =
# {
#     "response": [
#         {
#             "hostIp": "10.1.15.117",
#             "hostMac": "00:24:d7:43:59:d8",
#             "hostType": "wireless",
#             "connectedNetworkDeviceId": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#             "connectedNetworkDeviceIpAddress": "10.1.14.3",
#             "connectedAPMacAddress": "68:bc:0c:63:4a:b0",
#             "connectedAPName": "AP7081.059f.19ca",
#             "vlanId": "600",
#             "lastUpdated": "1479514114932",
#             "source": "200",
#             "pointOfPresence": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#             "pointOfAttachment": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#             "subType": "UNKNOWN",
#             "id": "48cdeb9b-b412-491e-a80c-7ec5bbe98167"
#         }
#     ],
#     "version": "1.0"
# }

# %% [markdown]
# ### Manage Users

# %%
def getUsers(ticket):
    print("\nGetting list of existing users")
    # URL for user REST API call to get list of APIC-EM users.
    url = "https://" + controller + "/api/v1/user"

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}

    # this statement performs a GET on the specified host url
    response = requests.get(url, headers=header, verify=False)

    # json.dumps serializes the json into a string and allows us to
    # print the response in a 'pretty' format with indentation etc.
    print ("Users = ")
    print (json.dumps(response.json(), indent=4, separators=(',', ': ')))

    
#Adds a APIC-EM User
def addUser(ticket):
    print("\nAdding new user")
    # URL for user REST API call to get list of existing users in the network.
    url = "https://" + controller + "/api/v1/user"

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}
    
    username="brett"
    #Data for new user
    payload={"password":"Brett123!","username":username,"authorization":[{"scope":"ALL","role":"ROLE_OBSERVER"}]}
    
    # this statement performs a Post on the specified user url
    response = requests.post(url, data=json.dumps(payload), headers=header, verify=False)
    print ("Response after post:  " + response.text)
    
    return (username)


#Delete the user that corresponds to the passed in username parameter
def deleteUser(username, ticket):
    print("\nRemoving user: " + username)
    # URL for a specified user REST API call.
    url = "https://" + controller + "/api/v1/user/" + username

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}

    # this statement performs a Delete on the specified user url
    response = requests.delete(url, headers=header, verify=False)
    print (response.text)

    
#Show the User that corresponds to the passed in username parameter
def showUser(username, ticket):
    print("\nDisplaying user: " + username)
    # URL for user REST API call to get APIC-EM user with corresponding name.
    url = "https://" + controller + "/api/v1/user/" + username

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}

    # this statement performs a GET on the specified user url
    response = requests.get(url, headers=header, verify=False)
    
    # json.dumps serializes the json into a string and allows us to
    # print the response in a 'pretty' format with indentation etc.
    print ("User found = ")
    print (json.dumps(response.json(), indent=4, separators=(',', ': ')))
    


theTicket=getTicket()
getUsers(theTicket)
name=addUser(theTicket)
showUser(name,theTicket)
getUsers(theTicket)
deleteUser(name,theTicket)
getUsers(theTicket)
# Out:
# <Response [200]>
#
# Getting list of existing users
# Users =
# {
#     "response": [
#         {
#             "username": "devnetuser",
#             "authorization": [
#                 {
#                     "scope": "ALL",
#                     "role": "ROLE_POLICY_ADMIN"
#                 }
#             ],
#             "authSource": "internal"
#         }
#     ],
#     "version": "1.0"
# }
#
# Adding new user
# Response after post:  { "response":{"errorCode":"RBAC","message":"You do not have permissions to access this resource","detail":"You do not have permissions to access this resource"}, "version":"1.0"}
#
#
# Displaying user: brett
# User found =
# {
#     "response": {
#         "errorCode": "Unauthorized",
#         "message": "You do not have permissions to access this resource",
#         "detail": "User does not have sufficient privileges to access API"
#     },
#     "version": "1.0"
# }
#
# Getting list of existing users
# Users =
# {
#     "response": [
#         {
#             "username": "devnetuser",
#             "authorization": [
#                 {
#                     "scope": "ALL",
#                     "role": "ROLE_POLICY_ADMIN"
#                 }
#             ],
#             "authSource": "internal"
#         }
#     ],
#     "version": "1.0"
# }
#
# Removing user: brett
# { "response":{"errorCode":"RBAC","message":"You do not have permissions to access this resource","detail":"You do not have permissions to access this resource"}, "version":"1.0"}
#
#
# Getting list of existing users
# Users =
# {
#     "response": [
#         {
#             "username": "devnetuser",
#             "authorization": [
#                 {
#                     "scope": "ALL",
#                     "role": "ROLE_POLICY_ADMIN"
#                 }
#             ],
#             "authSource": "internal"
#         }
#     ],
#     "version": "1.0"
# }

# %% [markdown]
# ### Report Topology

# %%
def getTopology():
    
    ticket=getTicket()
    # URL for topology REST API call to get list of existing devices on the network, and build topology
    url = "https://" + controller + "/api/v1/topology/physical-topology"

    #Content type as well as the ticket must be included in the header 
    header = {"content-type": "application/json", "X-Auth-Token":ticket}

    # this statement performs a GET on the specified network device url
    response = requests.get(url, headers=header, verify=False)

    # json.dumps serializes the json into a string and allows us to
    # print the response in a 'pretty' format with indentation etc.
    print ("Topology = ")
    print (json.dumps(response.json(), indent=4, separators=(',', ': ')))
    
    #convert data to json format.
    r_json=response.json()
    
    net_nodes=[]
    #Iterate through network device data and list the nodes, their interfaces, status and to what they connect    
    for n in r_json["response"]["nodes"]:
        if "platformId" in n:
            print()
            print()
            print('{:30}'.format("Node") + '{:25}'.format("Family") + '{:20}'.format("Label")+ "Management IP")
            print('{:30}'.format(n["platformId"]) + '{:25}'.format(n["family"]) + '{:20}'.format(n["label"]) + n["ip"])
            net_nodes.append(n["label"])
            
        found=0    #print header flag        
        for i in r_json["response"]["links"]:
            if "startPortName" in i:
                #check that the source device id for the interface matches the node id.  Means interface originated from this device. 
                if i["source"] == n["id"]:
                    if found==0:
                        print('{:>20}'.format("Source Interface") + '{:>15}'.format("Target") +'{:>28}'.format("Target Interface") + '{:>15}'.format("Status") )
                        found=1                                            
                    for n1 in r_json["response"]["nodes"]:
                        #find name of node to which this one connects
                        if i["target"] == n1["id"]:
                            print("    " + '{:<25}'.format(i["startPortName"]) + '{:<18}'.format(n1["platformId"]) + '{:<25}'.format(i["endPortName"]) + '{:<9}'.format(i["linkStatus"]) )                            
                            break
        
    return net_nodes
    
    
theNodes=getTopology()
nodestr=""
for node in theNodes:
    nodestr=nodestr + node + " "
setHeaders()
room_id=createRoom("Brett's Room")
addMembers(room_id)   # Passing roomId to members function here to Post Message.
postMsg(room_id,"Network nodes are " + nodestr)      # Passing roomId to message function here to Post Message.
# Out:
# <Response [200]>
# Topology =
# {
#     "response": {
#         "nodes": [
#             {
#                 "deviceType": "Cisco 2911 Integrated Services Router G2",
#                 "label": "Branch-Router1",
#                 "ip": "10.2.2.1",
#                 "softwareVersion": "15.2(4)M6a",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "CISCO2911/K9",
#                 "tags": [
#                     "test3"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "0dd240fd-5cca-4774-a801-9f1c04edcc70"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 6503 Switch",
#                 "label": "CAMPUS-Core2",
#                 "ip": "10.1.10.1",
#                 "softwareVersion": "15.2(1)SY1",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C6503-E",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "1b329f52-95eb-44ad-9314-55932162ab86"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 29xx Stack-able Ethernet Switch",
#                 "label": "Branch-Access1",
#                 "ip": "10.2.1.17",
#                 "softwareVersion": "12.2(55)SE3",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C2960S-48LPS-L",
#                 "tags": [
#                     "test3",
#                     "test",
#                     "Test1"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "26450a30-57d8-4b56-b8f1-6fc535d67645"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 6503 Switch",
#                 "label": "CAMPUS-Core1",
#                 "ip": "10.1.7.1",
#                 "softwareVersion": "15.2(1)SY1",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C6503-E",
#                 "tags": [],
#                 "role": "CORE",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "30d39b18-9ada-4148-ad6c-2ee20975b845"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 4507R plus E Switch",
#                 "label": "CAMPUS-Dist2",
#                 "ip": "10.1.11.1",
#                 "softwareVersion": "03.04.00.SG",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C4507R+E",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22"
#             },
#             {
#                 "deviceType": "Cisco 4451 Series Integrated Services Router",
#                 "label": "CAMPUS-Router2",
#                 "ip": "10.1.4.2",
#                 "softwareVersion": "15.4(3)S",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "ISR4451-X/K9",
#                 "tags": [
#                     "test3",
#                     "Test1"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "55450140-de19-47b5-ae80-bfd741b23fd9"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 3850-48U-E Switch",
#                 "label": "CAMPUS-Access1",
#                 "ip": "10.1.12.1",
#                 "softwareVersion": "03.06.04.E",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C3850-48U",
#                 "tags": [],
#                 "role": "CORE",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "5b5ea8da-8c23-486a-b95e-7429684d25fc"
#             },
#             {
#                 "deviceType": "Cisco 2911 Integrated Services Router G2",
#                 "label": "Branch-Router2",
#                 "ip": "10.2.2.2",
#                 "softwareVersion": "15.2(4)M6a",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "CISCO2911/K9",
#                 "tags": [
#                     "test3",
#                     "Test1"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "6ce631db-9212-4587-867f-b8f3aed1702d"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 2960C-8PC-L Switch",
#                 "label": "AHEC-2960C1",
#                 "ip": "165.10.1.39",
#                 "softwareVersion": "15.2(2.5.72)E4",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C2960C-8PC-L",
#                 "tags": [
#                     "test3",
#                     "test",
#                     "Test1"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7"
#             },
#             {
#                 "deviceType": "Cisco 4451 Series Integrated Services Router",
#                 "label": "CAMPUS-Router1",
#                 "ip": "10.1.2.1",
#                 "softwareVersion": "15.4(3)S",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "ISR4451-X/K9",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7"
#             },
#             {
#                 "deviceType": "Cisco 5508 Wireless LAN Controller",
#                 "label": "Campus-WLC-5508",
#                 "ip": "10.1.14.2",
#                 "softwareVersion": "8.1.14.16",
#                 "nodeType": "device",
#                 "family": "Wireless Controller",
#                 "platformId": "AIR-CT5508-K9",
#                 "tags": [
#                     "test3",
#                     "Test1"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "MANUAL",
#                 "customParam": {},
#                 "id": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3"
#             },
#             {
#                 "deviceType": "Cisco Catalyst 4507R plus E Switch",
#                 "label": "CAMPUS-Dist1",
#                 "ip": "10.255.1.5",
#                 "softwareVersion": "03.02.00.XO",
#                 "nodeType": "device",
#                 "family": "Switches and Hubs",
#                 "platformId": "WS-C4507R+E",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "DISTRIBUTION",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "c8ed3e49-5eeb-4dee-b120-edeb179c8394"
#             },
#             {
#                 "deviceType": "Cisco 3500I Unified Access Point",
#                 "label": "AP7081.059f.19ca",
#                 "ip": "10.1.14.3",
#                 "softwareVersion": "8.1.14.16",
#                 "nodeType": "device",
#                 "family": "Unified AP",
#                 "platformId": "AIR-CAP3502I-A-K9",
#                 "tags": [
#                     "Test1"
#                 ],
#                 "role": "ACCESS",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "cd6d9b24-839b-4d58-adfe-3fdf781e1782"
#             },
#             {
#                 "deviceType": "Cisco 2911 Integrated Services Router G2",
#                 "label": "Branch2-Router.yourdomain.com",
#                 "ip": "218.1.100.100",
#                 "softwareVersion": "15.2(4)M6a",
#                 "nodeType": "device",
#                 "family": "Routers",
#                 "platformId": "CISCO2911/K9",
#                 "tags": [
#                     "test"
#                 ],
#                 "role": "BORDER ROUTER",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "d337811b-d371-444c-a49f-9e2791f955b4"
#             },
#             {
#                 "deviceType": "wireless",
#                 "label": "10.1.15.117",
#                 "ip": "10.1.15.117",
#                 "nodeType": "HOST",
#                 "family": "WIRELESS",
#                 "role": "HOST",
#                 "customParam": {},
#                 "id": "48cdeb9b-b412-491e-a80c-7ec5bbe98167"
#             },
#             {
#                 "deviceType": "wired",
#                 "label": "10.1.12.20",
#                 "ip": "10.1.12.20",
#                 "nodeType": "HOST",
#                 "family": "WIRED",
#                 "role": "HOST",
#                 "customParam": {},
#                 "id": "572d4065-abd8-4b97-bfc3-ab5ee13f6c08"
#             },
#             {
#                 "deviceType": "wired",
#                 "label": "10.2.1.22",
#                 "ip": "10.2.1.22",
#                 "nodeType": "HOST",
#                 "family": "WIRED",
#                 "role": "HOST",
#                 "customParam": {},
#                 "id": "f624d4f3-0ab9-4ae3-b09d-62051edbd8f3"
#             },
#             {
#                 "deviceType": "cloud node",
#                 "label": "cloud node",
#                 "ip": "UNKNOWN",
#                 "softwareVersion": "UNKNOWN",
#                 "nodeType": "cloud node",
#                 "family": "cloud node",
#                 "platformId": "UNKNOWN",
#                 "tags": [
#                     "cloud node"
#                 ],
#                 "role": "cloud node",
#                 "roleSource": "AUTO",
#                 "customParam": {},
#                 "id": "e670f633-49c9-4132-9cac-bc91d730a555"
#             }
#         ],
#         "links": [
#             {
#                 "source": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "startPortID": "1ac5854f-4659-442f-9bd2-f775aa3b260a",
#                 "startPortName": "GigabitEthernet5/38",
#                 "startPortSpeed": "1000000",
#                 "target": "ae19cd21-1b26-4f58-8ccd-d265deabb6c3",
#                 "endPortID": "4f063bed-7ca8-49dc-8fd4-63ff1613d59f",
#                 "endPortName": "GigabitEthernet0/0/1",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97107"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "7710a7b4-fc96-43e4-a1bf-b002c052d6f2",
#                 "startPortName": "GigabitEthernet1/2",
#                 "startPortIpv4Address": "10.1.5.2",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#                 "endPortID": "6dc56935-8268-45e4-acaa-de1c15a8832d",
#                 "endPortName": "GigabitEthernet0/0/1",
#                 "endPortIpv4Address": "10.1.5.1",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97100"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "f8a45bfd-0e1f-4f3e-b56c-150e3a9fc103",
#                 "startPortName": "GigabitEthernet1/1",
#                 "startPortIpv4Address": "10.1.7.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "endPortID": "729002b4-a1cd-4700-a2f9-b68cbdfe2f70",
#                 "endPortName": "GigabitEthernet5/7",
#                 "endPortIpv4Address": "10.1.7.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97103"
#             },
#             {
#                 "source": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "startPortID": "05186c34-2ed8-4db4-bba3-ac9c2b68ad90",
#                 "startPortName": "GigabitEthernet1/0/1",
#                 "startPortSpeed": "1000000",
#                 "target": "6ce631db-9212-4587-867f-b8f3aed1702d",
#                 "endPortID": "1b46c64c-bb92-4998-bee2-283118075156",
#                 "endPortName": "GigabitEthernet0/2",
#                 "endPortIpv4Address": "10.2.1.19",
#                 "endPortIpv4Mask": "255.255.255.0",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97098"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "51338919-c3a8-401d-96d9-14cc1de9efda",
#                 "startPortName": "GigabitEthernet1/3",
#                 "startPortIpv4Address": "10.1.4.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "55450140-de19-47b5-ae80-bfd741b23fd9",
#                 "endPortID": "76fe51df-dee7-4041-944c-a49244172a00",
#                 "endPortName": "GigabitEthernet0/0/0",
#                 "endPortIpv4Address": "10.1.4.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97106"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "22f37b71-25f3-4b9a-945a-2c7d28345540",
#                 "startPortName": "TenGigabitEthernet1/5",
#                 "startPortIpv4Address": "10.1.10.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "10000000",
#                 "target": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "endPortID": "0b2984dd-7dbd-4cf3-9308-246bcf31673c",
#                 "endPortName": "TenGigabitEthernet3/1",
#                 "endPortIpv4Address": "10.1.10.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "10000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97102"
#             },
#             {
#                 "source": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#                 "startPortID": "117ef150-0fcd-4c34-9b7d-92c31af82627",
#                 "startPortName": "GigabitEthernet0/1",
#                 "startPortIpv4Address": "10.2.2.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "6ce631db-9212-4587-867f-b8f3aed1702d",
#                 "endPortID": "c21a4fd0-c571-4516-980e-3f118cb827ec",
#                 "endPortName": "GigabitEthernet0/1",
#                 "endPortIpv4Address": "10.2.2.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97114"
#             },
#             {
#                 "source": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "startPortID": "a6355c85-3577-4922-bfe5-1c08456b7cae",
#                 "startPortName": "GigabitEthernet1/0/2",
#                 "startPortSpeed": "1000000",
#                 "target": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#                 "endPortID": "4ab54405-1b5a-4ddc-9950-20af65f6806c",
#                 "endPortName": "GigabitEthernet0/2",
#                 "endPortIpv4Address": "10.2.1.18",
#                 "endPortIpv4Mask": "255.255.255.0",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97097"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "8e3fd588-deef-4dc8-9885-560e0f48bf49",
#                 "startPortName": "GigabitEthernet1/3",
#                 "startPortIpv4Address": "10.1.3.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "55450140-de19-47b5-ae80-bfd741b23fd9",
#                 "endPortID": "20c9326c-82b0-47b9-aee5-f57b7725bd01",
#                 "endPortName": "GigabitEthernet0/0/1",
#                 "endPortIpv4Address": "10.1.3.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97099"
#             },
#             {
#                 "source": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#                 "startPortID": "ea5e2530-a43e-4111-8858-719d7764b368",
#                 "startPortName": "GigabitEthernet0/0/2",
#                 "startPortIpv4Address": "10.1.1.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "55450140-de19-47b5-ae80-bfd741b23fd9",
#                 "endPortID": "cb43a099-28d6-4b3d-a741-fb2dbd024748",
#                 "endPortName": "GigabitEthernet0/0/2",
#                 "endPortIpv4Address": "10.1.1.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97113"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "e37e041c-e005-42e1-bce7-4c2587e10f76",
#                 "startPortName": "TenGigabitEthernet1/5",
#                 "startPortIpv4Address": "10.1.9.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "10000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "fa5b0690-8b64-4392-832d-b95f180dd5d8",
#                 "endPortName": "TenGigabitEthernet3/1",
#                 "endPortIpv4Address": "10.1.9.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "10000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97104"
#             },
#             {
#                 "source": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#                 "startPortID": "",
#                 "startPortName": "GigabitEthernet0",
#                 "startPortIpv4Address": " 10.  1. 14.  3",
#                 "startPortIpv4Mask": "255.255.255.  0",
#                 "startPortSpeed": "-1",
#                 "target": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "endPortID": "dd2c47ea-ad19-4a1e-ad0e-82d9deefd61b",
#                 "endPortName": "GigabitEthernet1/0/26",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97116"
#             },
#             {
#                 "source": "1b329f52-95eb-44ad-9314-55932162ab86",
#                 "startPortID": "f6a66400-3fda-4511-80af-4413f70f0827",
#                 "startPortName": "GigabitEthernet1/1",
#                 "startPortIpv4Address": "10.1.8.1",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "3dad05bd-1b78-466f-94fe-1921bc0e3c15",
#                 "endPortName": "GigabitEthernet5/7",
#                 "endPortIpv4Address": "10.1.8.2",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97101"
#             },
#             {
#                 "source": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "startPortID": "2c563c32-fefa-48f0-b960-160712f9f9f7",
#                 "startPortName": "GigabitEthernet5/48",
#                 "startPortIpv4Address": "10.1.11.2",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "146f21fa-bc0c-4081-bb22-affde24cdd9f",
#                 "endPortName": "GigabitEthernet5/48",
#                 "endPortIpv4Address": "10.1.11.1",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97108"
#             },
#             {
#                 "source": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "startPortID": "f1fc2715-25e0-4b92-9fa5-e34237cbc1c8",
#                 "startPortName": "GigabitEthernet1/0/2",
#                 "startPortSpeed": "1000000",
#                 "target": "4af8bf34-295f-46f4-97b7-0a2d2ea4cf22",
#                 "endPortID": "58f7c3b1-99df-4965-9c1f-c0a284772f64",
#                 "endPortName": "GigabitEthernet5/5",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97112"
#             },
#             {
#                 "source": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "startPortID": "38c72319-855e-43bc-8458-94f695d435b6",
#                 "startPortName": "GigabitEthernet1/0/1",
#                 "startPortSpeed": "1000000",
#                 "target": "c8ed3e49-5eeb-4dee-b120-edeb179c8394",
#                 "endPortID": "b10dcdea-1675-4509-b554-f047f6a37595",
#                 "endPortName": "GigabitEthernet5/5",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97110"
#             },
#             {
#                 "source": "30d39b18-9ada-4148-ad6c-2ee20975b845",
#                 "startPortID": "6df9d717-5c7a-479e-a595-563480aaada0",
#                 "startPortName": "GigabitEthernet1/2",
#                 "startPortIpv4Address": "10.1.2.2",
#                 "startPortIpv4Mask": "255.255.255.248",
#                 "startPortSpeed": "1000000",
#                 "target": "9712ab62-6140-43fd-b1ee-1b07d1fb67d7",
#                 "endPortID": "43ee5993-b8a0-4ed8-8c1b-376273834582",
#                 "endPortName": "GigabitEthernet0/0/0",
#                 "endPortIpv4Address": "10.1.2.1",
#                 "endPortIpv4Mask": "255.255.255.248",
#                 "endPortSpeed": "1000000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97105"
#             },
#             {
#                 "source": "8dbd8068-1091-4cde-8cf5-d1b58dc5c9c7",
#                 "startPortID": "8d235543-bb80-4423-b66f-1e9ad45d08e6",
#                 "startPortName": "FastEthernet0/1",
#                 "startPortSpeed": "100000",
#                 "target": "d337811b-d371-444c-a49f-9e2791f955b4",
#                 "endPortID": "fc78fa72-a37e-46c7-9f47-137789295e35",
#                 "endPortName": "GigabitEthernet0/0.1",
#                 "endPortIpv4Address": "165.10.1.100",
#                 "endPortIpv4Mask": "255.255.255.0",
#                 "endPortSpeed": "100000",
#                 "linkStatus": "up",
#                 "greyOut": true,
#                 "id": "97118"
#             },
#             {
#                 "source": "cd6d9b24-839b-4d58-adfe-3fdf781e1782",
#                 "target": "48cdeb9b-b412-491e-a80c-7ec5bbe98167",
#                 "linkStatus": "UP",
#                 "greyOut": true
#             },
#             {
#                 "source": "5b5ea8da-8c23-486a-b95e-7429684d25fc",
#                 "startPortID": "6e4e5ae6-6045-4060-9038-1a64d5a101cc",
#                 "target": "572d4065-abd8-4b97-bfc3-ab5ee13f6c08",
#                 "linkStatus": "UP",
#                 "greyOut": true
#             },
#             {
#                 "source": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "startPortID": "7075521d-4d7b-4218-92f9-79b60e054635",
#                 "target": "f624d4f3-0ab9-4ae3-b09d-62051edbd8f3",
#                 "linkStatus": "UP",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "0dd240fd-5cca-4774-a801-9f1c04edcc70",
#                 "linkStatus": "up",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "26450a30-57d8-4b56-b8f1-6fc535d67645",
#                 "linkStatus": "up",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "6ce631db-9212-4587-867f-b8f3aed1702d",
#                 "linkStatus": "up",
#                 "greyOut": true
#             },
#             {
#                 "source": "e670f633-49c9-4132-9cac-bc91d730a555",
#                 "target": "d337811b-d371-444c-a49f-9e2791f955b4",
#                 "linkStatus": "up",
#                 "greyOut": true
#             }
#         ]
#     },
#     "version": "1.0"
# }
#
#
# Node                          Family                   Label               Management IP
# CISCO2911/K9                  Routers                  Branch-Router1      10.2.2.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet0/1       CISCO2911/K9      GigabitEthernet0/1       up
#
#
# Node                          Family                   Label               Management IP
# WS-C6503-E                    Switches and Hubs        CAMPUS-Core2        10.1.10.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/2       ISR4451-X/K9      GigabitEthernet0/0/1     up
#     TenGigabitEthernet1/5    WS-C4507R+E       TenGigabitEthernet3/1    up
#     GigabitEthernet1/3       ISR4451-X/K9      GigabitEthernet0/0/1     up
#     GigabitEthernet1/1       WS-C4507R+E       GigabitEthernet5/7       up
#
#
# Node                          Family                   Label               Management IP
# WS-C2960S-48LPS-L             Switches and Hubs        Branch-Access1      10.2.1.17
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/0/1     CISCO2911/K9      GigabitEthernet0/2       up
#     GigabitEthernet1/0/2     CISCO2911/K9      GigabitEthernet0/2       up
#
#
# Node                          Family                   Label               Management IP
# WS-C6503-E                    Switches and Hubs        CAMPUS-Core1        10.1.7.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/1       WS-C4507R+E       GigabitEthernet5/7       up
#     GigabitEthernet1/3       ISR4451-X/K9      GigabitEthernet0/0/0     up
#     TenGigabitEthernet1/5    WS-C4507R+E       TenGigabitEthernet3/1    up
#     GigabitEthernet1/2       ISR4451-X/K9      GigabitEthernet0/0/0     up
#
#
# Node                          Family                   Label               Management IP
# WS-C4507R+E                   Switches and Hubs        CAMPUS-Dist2        10.1.11.1
#
#
# Node                          Family                   Label               Management IP
# ISR4451-X/K9                  Routers                  CAMPUS-Router2      10.1.4.2
#
#
# Node                          Family                   Label               Management IP
# WS-C3850-48U                  Switches and Hubs        CAMPUS-Access1      10.1.12.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet1/0/2     WS-C4507R+E       GigabitEthernet5/5       up
#     GigabitEthernet1/0/1     WS-C4507R+E       GigabitEthernet5/5       up
#
#
# Node                          Family                   Label               Management IP
# CISCO2911/K9                  Routers                  Branch-Router2      10.2.2.2
#
#
# Node                          Family                   Label               Management IP
# WS-C2960C-8PC-L               Switches and Hubs        AHEC-2960C1         165.10.1.39
#     Source Interface         Target            Target Interface         Status
#     FastEthernet0/1          CISCO2911/K9      GigabitEthernet0/0.1     up
#
#
# Node                          Family                   Label               Management IP
# ISR4451-X/K9                  Routers                  CAMPUS-Router1      10.1.2.1
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet0/0/2     ISR4451-X/K9      GigabitEthernet0/0/2     up
#
#
# Node                          Family                   Label               Management IP
# AIR-CT5508-K9                 Wireless Controller      Campus-WLC-5508     10.1.14.2
#
#
# Node                          Family                   Label               Management IP
# WS-C4507R+E                   Switches and Hubs        CAMPUS-Dist1        10.255.1.5
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet5/38      AIR-CT5508-K9     GigabitEthernet0/0/1     up
#     GigabitEthernet5/48      WS-C4507R+E       GigabitEthernet5/48      up
#
#
# Node                          Family                   Label               Management IP
# AIR-CAP3502I-A-K9             Unified AP               AP7081.059f.19ca    10.1.14.3
#     Source Interface         Target            Target Interface         Status
#     GigabitEthernet0         WS-C3850-48U      GigabitEthernet1/0/26    up
#
#
# Node                          Family                   Label               Management IP
# CISCO2911/K9                  Routers                  Branch2-Router.yourdomain.com218.1.100.100
#
#
# Node                          Family                   Label               Management IP
# UNKNOWN                       cloud node               cloud node          UNKNOWN
# SparkAPI:  <Response [401]>
# {'message': 'The request requires a valid access token set in the Authorization request header.', 'errors': [{'description': 'The request requires a valid access token set in the Authorization request header.'}], 'trackingId': 'ROUTER_5E50CD9B-2A3A-01BB-00F7-7D4BA75D00F7'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-00c5a4c48d91> in <module>
#      51     nodestr=nodestr + node + " "
#      52 setHeaders()
# ---> 53 room_id=createRoom("Brett's Room")
#      54 addMembers(room_id)   # Passing roomId to members function here to Post Message.
#      55 postMsg(room_id,"Network nodes are " + nodestr)      # Passing roomId to message function here to Post Message.
#
# D:\class\yeslab\新网工\Basic\直播\LAB\helper\spark.py in createRoom(room_name)
#      17     print("SparkAPI: ",resp)
#      18     print(resp.json())
# ---> 19     print("Newly Created RoomId: ", resp.json()['id'])  # You will need this roomId to post Messages to it
#      20     return resp.json()['id']
#      21
#
# KeyError: 'id'
